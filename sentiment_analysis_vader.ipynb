# %%
import nltk
import pandas as pd
import numpy as np
#  nltk.download('vader_lexicon')

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
# Out:
# /opt/anaconda3/envs/nlp/lib/python3.7/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df = pd.read_csv("biden_tweets.csv")
df.head()
# Out:
#                                                 text  favorited  \
# 0  In honor of John Lewis, C.T. Vivian, and all t...      False
# 1  Folks, it may be hard to believe, but we have ...      False
# 2  Small manufacturers like McGregor Industries d...      False
# 3  Today, I am putting the Kremlin and other fore...      False
# 4  We're paying the price for this president's in...      False
#
#    favoriteCount  replyToSN               created  truncated  replyToSID  \
# 0          43392        NaN  2020-07-21T01:15:00Z       True         NaN
# 1          16936        NaN  2020-07-21T00:20:00Z       True         NaN
# 2           7504        NaN  2020-07-20T23:05:00Z       True         NaN
# 3          89672        NaN  2020-07-20T21:55:00Z       True         NaN
# 4          48258        NaN  2020-07-20T21:10:00Z      False         NaN
#
#                     id  replyToUID  \
# 0  1285382736341942274         NaN
# 1  1285368895155474432         NaN
# 2  1285350020942901255         NaN
# 3  1285332404647784449         NaN
# 4  1285321080039669763         NaN
#
#                                         statusSource screenName  retweetCount  \
# 0  <a href="https://about.twitter.com/products/tw...   JoeBiden          8195
# 1  <a href="https://about.twitter.com/products/tw...   JoeBiden          3959
# 2  <a href="https://studio.twitter.com" rel="nofo...   JoeBiden          2002
# 3  <a href="https://about.twitter.com/products/tw...   JoeBiden         23020
# 4  <a href="https://mobile.twitter.com" rel="nofo...   JoeBiden         10503
#
#    isRetweet  retweeted  longitude  latitude
# 0      False      False        NaN       NaN
# 1      False      False        NaN       NaN
# 2      False      False        NaN       NaN
# 3      False      False        NaN       NaN
# 4      False      False        NaN       NaN

# %%
df['scores'] = df['text'].apply(lambda review: sid.polarity_scores(review))
df.head()
# Out:
#                                                 text  favorited  \
# 0  In honor of John Lewis, C.T. Vivian, and all t...      False
# 1  Folks, it may be hard to believe, but we have ...      False
# 2  Small manufacturers like McGregor Industries d...      False
# 3  Today, I am putting the Kremlin and other fore...      False
# 4  We're paying the price for this president's in...      False
#
#    favoriteCount  replyToSN               created  truncated  replyToSID  \
# 0          43392        NaN  2020-07-21T01:15:00Z       True         NaN
# 1          16936        NaN  2020-07-21T00:20:00Z       True         NaN
# 2           7504        NaN  2020-07-20T23:05:00Z       True         NaN
# 3          89672        NaN  2020-07-20T21:55:00Z       True         NaN
# 4          48258        NaN  2020-07-20T21:10:00Z      False         NaN
#
#                     id  replyToUID  \
# 0  1285382736341942274         NaN
# 1  1285368895155474432         NaN
# 2  1285350020942901255         NaN
# 3  1285332404647784449         NaN
# 4  1285321080039669763         NaN
#
#                                         statusSource screenName  retweetCount  \
# 0  <a href="https://about.twitter.com/products/tw...   JoeBiden          8195
# 1  <a href="https://about.twitter.com/products/tw...   JoeBiden          3959
# 2  <a href="https://studio.twitter.com" rel="nofo...   JoeBiden          2002
# 3  <a href="https://about.twitter.com/products/tw...   JoeBiden         23020
# 4  <a href="https://mobile.twitter.com" rel="nofo...   JoeBiden         10503
#
#    isRetweet  retweeted  longitude  latitude  \
# 0      False      False        NaN       NaN
# 1      False      False        NaN       NaN
# 2      False      False        NaN       NaN
# 3      False      False        NaN       NaN
# 4      False      False        NaN       NaN
#
#                                               scores
# 0  {'neg': 0.079, 'neu': 0.788, 'pos': 0.133, 'co...
# 1  {'neg': 0.05, 'neu': 0.95, 'pos': 0.0, 'compou...
# 2  {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'comp...

# %%
df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])
df.head(20)
# Out:
#             id                                               link  \
# 0   1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1   1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2   1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3   1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4   1773561338  https://twitter.com/realDonaldTrump/status/177...
# 5   1776419923  https://twitter.com/realDonaldTrump/status/177...
# 6   1786560616  https://twitter.com/realDonaldTrump/status/178...
# 7   1796477499  https://twitter.com/realDonaldTrump/status/179...
# 8   1806258917  https://twitter.com/realDonaldTrump/status/180...
# 9   1820624395  https://twitter.com/realDonaldTrump/status/182...
# 10  1826225450  https://twitter.com/realDonaldTrump/status/182...
# 11  1836131903  https://twitter.com/realDonaldTrump/status/183...
# 12  1849558306  https://twitter.com/realDonaldTrump/status/184...
# 13  1859044981  https://twitter.com/realDonaldTrump/status/185...
# 14  1864367186  https://twitter.com/realDonaldTrump/status/186...
# 15  1878373267  https://twitter.com/realDonaldTrump/status/187...
# 16  1884022748  https://twitter.com/realDonaldTrump/status/188...
# 17  1894284587  https://twitter.com/realDonaldTrump/status/189...
# 18  1924074459  https://twitter.com/realDonaldTrump/status/192...
# 19  1936022874  https://twitter.com/realDonaldTrump/status/193...
#
#                                               content                 date  \
# 0   Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1   Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2   Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3   New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4   "My persona will never be that of a wallflower...  2009-05-12 09:07:28
# 5   Miss USA Tara Conner will not be fired - "I've...  2009-05-12 14:21:55
# 6   Listen to an interview with Donald Trump discu...  2009-05-13 12:38:28
# 7   "Strive for wholeness and keep your sense of w...  2009-05-14 11:30:40
# 8   Enter the "Think Like A Champion" signed book ...  2009-05-15 09:13:13
# 9   "When the achiever achieves, it's not a platea...  2009-05-16 17:22:45
# 10  "Don’t be afraid of being unique - it's like b...  2009-05-17 10:00:03
# 11  "We win in our lives by having a champion's vi...  2009-05-18 09:26:00
# 12  "...these days...we could all use a little of ...  2009-05-19 12:43:39
# 13  "Always know you could be on the precipice of ...  2009-05-20 08:25:39
# 14  Read a great interview with Donald Trump that ...  2009-05-20 17:29:47
# 15  "Keep it fast, short and direct - whatever it ...  2009-05-21 21:59:39
# 16  Don't forget to enter the "Think Like A Champi...  2009-05-22 11:28:34
# 17  Did you know Donald Trump is on Facebook? http...  2009-05-23 11:11:19
# 18  "Your higher self is in direct opposition to y...  2009-05-26 09:42:01
# 19  Read an excerpt from Think Like A Champion by ...  2009-05-27 09:18:52
#
#     retweets  favorites mentions hashtags  \
# 0        510        917      NaN      NaN
# 1         34        267      NaN      NaN
# 2         13         19      NaN      NaN
# 3         11         26      NaN      NaN
# 4       1375       1945      NaN      NaN
# 5         29         28      NaN      NaN
# 6         15         16      NaN      NaN
# 7         18         27      NaN      NaN
# 8         15          9      NaN      NaN
# 9         19         47      NaN      NaN
# 10        40         69      NaN      NaN
# 11        74        122      NaN      NaN
# 12        23         23      NaN      NaN
# 13        28         51      NaN      NaN
# 14        10         11      NaN      NaN
# 15        61         82      NaN      NaN
# 16        13          5      NaN      NaN
# 17        58         79      NaN      NaN
# 18        50         81      NaN      NaN
# 19         6         12      NaN      NaN
#
#                                                scores  compound
# 0   {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'comp...    0.5255
# 1   {'neg': 0.0, 'neu': 0.74, 'pos': 0.26, 'compou...    0.7712
# 2   {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'comp...    0.6468
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 5   {'neg': 0.078, 'neu': 0.78, 'pos': 0.142, 'com...    0.3235
# 6   {'neg': 0.0, 'neu': 0.67, 'pos': 0.33, 'compou...    0.7506
# 7   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 8   {'neg': 0.0, 'neu': 0.584, 'pos': 0.416, 'comp...    0.7506
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 10  {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'comp...    0.7717
# 11  {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'comp...    0.5859
# 12  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 14  {'neg': 0.0, 'neu': 0.773, 'pos': 0.227, 'comp...    0.6249
# 15  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000
# 16  {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...    0.7944
# 17  {'neg': 0.0, 'neu': 0.809, 'pos': 0.191, 'comp...    0.3802
# 18  {'neg': 0.0, 'neu': 0.848, 'pos': 0.152, 'comp...    0.3612
# 19  {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compou...    0.7506

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
df.head()
# Out:
#            id                                               link  \
# 0  1698308935  https://twitter.com/realDonaldTrump/status/169...
# 1  1701461182  https://twitter.com/realDonaldTrump/status/170...
# 2  1737479987  https://twitter.com/realDonaldTrump/status/173...
# 3  1741160716  https://twitter.com/realDonaldTrump/status/174...
# 4  1773561338  https://twitter.com/realDonaldTrump/status/177...
#
#                                              content                 date  \
# 0  Be sure to tune in and watch Donald Trump on L...  2009-05-04 13:54:25
# 1  Donald Trump will be appearing on The View tom...  2009-05-04 20:00:10
# 2  Donald Trump reads Top Ten Financial Tips on L...  2009-05-08 08:38:08
# 3  New Blog Post: Celebrity Apprentice Finale and...  2009-05-08 15:40:15
# 4  "My persona will never be that of a wallflower...  2009-05-12 09:07:28
#
#    retweets  favorites mentions hashtags  \
# 0       510        917      NaN      NaN
# 1        34        267      NaN      NaN
# 2        13         19      NaN      NaN
# 3        11         26      NaN      NaN
# 4      1375       1945      NaN      NaN
#
#                                               scores  compound comp_score
# 0  {'neg': 0.0, 'neu': 0.827, 'pos': 0.173, 'comp...    0.5255        pos
# 1  {'neg': 0.0, 'neu': 0.74, 'pos': 0.26, 'compou...    0.7712        pos
# 2  {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'comp...    0.6468        pos
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos
# 4  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000        pos

# %%
df.to_csv("realdonaldtrump_vader.csv")
